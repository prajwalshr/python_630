# %%
file = open('data.csv', 'x')
file.close()

# %%
#to install pandas
# !pip install pandas

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#    sn    name  age        add
# 0   1     Ram   34  Kathmandu
# 1   2   Shyam   45  Bhaktapur
# 2   3    Hari   44   Lalitpur
# 3   4   Bryab   55      Jhapa
# 4   5  Andrew   89    Chitwan
# 5   6  Sabina   34    Chitwan

# %%
df.head()
# Out:
#    sn    name  age        add
# 0   1     Ram   34  Kathmandu
# 1   2   Shyam   45  Bhaktapur
# 2   3    Hari   44   Lalitpur
# 3   4   Bryab   55      Jhapa
# 4   5  Andrew   89    Chitwan

# %%
df.head(4)
# Out:
#    sn   name  age        add
# 0   1    Ram   34  Kathmandu
# 1   2  Shyam   45  Bhaktapur
# 2   3   Hari   44   Lalitpur
# 3   4  Bryab   55      Jhapa

# %%
df.tail()
# Out:
#    sn    name  age        add
# 1   2   Shyam   45  Bhaktapur
# 2   3    Hari   44   Lalitpur
# 3   4   Bryab   55      Jhapa
# 4   5  Andrew   89    Chitwan
# 5   6  Sabina   34    Chitwan

# %%
#Removing column index
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df
# Out:
#       name  age        add
# sn
# 1      Ram   34  Kathmandu
# 2    Shyam   45  Bhaktapur
# 3     Hari   44   Lalitpur
# 4    Bryab   55      Jhapa
# 5   Andrew   89    Chitwan
# 6   Sabina   34    Chitwan

# %%
#Removing column index
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn', usecols = ['sn','name','add'])
df
# Out:
#       name        add
# sn
# 1      Ram  Kathmandu
# 2    Shyam  Bhaktapur
# 3     Hari   Lalitpur
# 4    Bryab      Jhapa
# 5   Andrew    Chitwan
# 6   Sabina    Chitwan

# %%
#getting certian rows
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df.iloc[1:5]
# Out:
#       name  age        add
# sn
# 2    Shyam   45  Bhaktapur
# 3     Hari   44   Lalitpur
# 4    Bryab   55      Jhapa
# 5   Andrew   89    Chitwan

# %%
##getting certian rows and columns
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'sn')
df.iloc[1:5,0:2]
# Out:
#       name  age
# sn
# 2    Shyam   45
# 3     Hari   44
# 4    Bryab   55
# 5   Andrew   89

# %%
df
# Out:
#       name  age        add
# sn
# 1      Ram   34  Kathmandu
# 2    Shyam   45  Bhaktapur
# 3     Hari   44   Lalitpur
# 4    Bryab   55      Jhapa
# 5   Andrew   89    Chitwan
# 6   Sabina   34    Chitwan

# %%
df.loc[2:5]
# Out:
#       name  age        add
# sn
# 2    Shyam   45  Bhaktapur
# 3     Hari   44   Lalitpur
# 4    Bryab   55      Jhapa
# 5   Andrew   89    Chitwan

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'name')
df.loc['Ram':'Sabina']
# Out:
#         sn  age        add
# name
# Ram      1   34  Kathmandu
# Shyam    2   45  Bhaktapur
# Hari     3   44   Lalitpur
# Bryab    4   55      Jhapa
# Andrew   5   89    Chitwan
# Sabina   6   34    Chitwan

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df['add']
# Out:
# sn
# 1    Kathmandu
# 2    Bhaktapur
# 3     Lalitpur
# 4        Jhapa
# 5      Chitwan
# 6      Chitwan
# Name: add, dtype: object

# %%
#converting into list
df = pd.read_csv('data.csv',index_col = 'sn')
list(df['add'])
# Out:
# ['Kathmandu', 'Bhaktapur', 'Lalitpur', 'Jhapa', 'Chitwan', 'Chitwan']

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df[df['add'] == "Chitwan"]
# Out:
#       name  age      add
# sn
# 5   Andrew   89  Chitwan
# 6   Sabina   34  Chitwan

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6 entries, 1 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   age     5 non-null      float64
#  2   add     6 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 192.0+ bytes

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df['age'] < 100
df[df['age'] < 60]
# Out:
#       name  age        add
# sn
# 1      Ram   34  Kathmandu
# 2    Shyam   45  Bhaktapur
# 3     Hari   44   Lalitpur
# 4    Bryab   55      Jhapa
# 6   Sabina   34    Chitwan

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df[(df['age'] < 60) & (df['add'] == 'Chitwan')]
# Out:
#       name  age      add
# sn
# 6   Sabina   34  Chitwan

# %%
df = pd.read_csv('data.csv',index_col = 'sn')
df[(df['age'] < 60) & (df['add'] == 'Chitwan')].to_csv('trial.csv')

# %%
# DataFrame is a data type
data = {'name': ['Ram', 'Sita'],
        'age': [45,89],
        'add': ['KTM', 'Bhaktapur']}

df = pd.DataFrame(data)
#df.to_csv('news_data.csv')
df
# Out:
#    name  age        add
# 0   Ram   45        KTM
# 1  Sita   89  Bhaktapur

# %%
# DataFrame is a data type, used primarily for dictionary
data = {'name': ['Ram', 'Sita'],
        'age': [45,89],
        'add': ['KTM', 'Bhaktapur']}

df = pd.DataFrame(data)
df.to_json('news_data.json')
df
# Out:
#    name  age        add
# 0   Ram   45        KTM
# 1  Sita   89  Bhaktapur
